# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
print(tips.sex.value_counts())
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
# total number of female who are smokers
tips[(tips['sex']=='Female') & (tips['smoker']=='Yes')].shape
# Out:
# (33, 7)

# %%
import pandas as pd
pd.crosstab(tips['sex'],tips['smoker'])
# Out:
# smoker  No  Yes
# sex
# Female  54   33
# Male    97   60

# %%
# how many people gave tip of more than 5 dollars
print(pd.value_counts(tips['tip']>5))
print(tips[tips['tip']>5].shape)
# Out:
# False    226
# True      18
# Name: tip, dtype: int64
# (18, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.groupby(tips['sex'])['tip'].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
IQR=24.127-13.347

# %%
outliers=tips[(tips['total_bill']<(13.347-1.5*(IQR))) | (tips['total_bill']>(24.127+1.5*(IQR)))]

# %%
 outliers.head()
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3

# %%
import matplotlib.pyplot as plt
import pandas as pd

# to see the plots in the notebook

# %matplotlib inline

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#Scatter plots
plt.plot(tips['total_bill'],tips['tip'],'o')
plt.xlabel("total_bill")
plt.ylabel("tip")
plt.title("Total_bill Vs Tip")
# Out:
# Text(0.5,1,'Total_bill Vs Tip')

# %%
plt.hist(tips['total_bill'],density=False,bins=10,cumulative=False,align='mid')
plt.xlabel("Total_bill in Dollars")
plt.ylabel("frequeny")
# Out:
# Text(0,0.5,'frequeny')

# %%
plt.boxplot(tips['total_bill'],vert=False,showfliers=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x9f1c094da0>,
#   <matplotlib.lines.Line2D at 0x9f1c09d278>],
#  'caps': [<matplotlib.lines.Line2D at 0x9f1c09d6a0>,
#   <matplotlib.lines.Line2D at 0x9f1c09da58>],
#  'boxes': [<matplotlib.lines.Line2D at 0x9f1c094c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x9f1c09de80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9f1c0a72e8>],
#  'means': []}

# %%
import seaborn as sns

# %%
#distribution plot
sns.distplot(tips['total_bill'])
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Joint plot: need atleast 2 "variables
sns.jointplot(tips['total_bill'],tips['tip'],kind="reg")
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="total_bill",y="tip", data=tips)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.countplot(tips['sex'])

# %%
sns.boxplot(tips['total_bill'],tips['sex'])

# %%
sns.boxplot(x="day",y="total_bill",data=tips)

# %%
sns.boxplot(data=tips,palette="rainbow")
