# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from pycaret.classification import *

# %%
df1=pd.read_csv('NID_revised_cleanData.csv')
df1.head()
# Out:
#      Region        Metro SiteType DeploymentType                 NIDPM  \
# 0  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 1  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 2  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 3  AMEREAST     Campinas      RNG            Aug           Kathy Brown
# 4  AMERWEST  Los Angeles       GW        Upgrade  Darren (Norm) Norman
#
#                                                 DPM  IsMainstream  \
# 0       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 1       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 2       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 3          Madhvi Chand (Tata Consultancy Services)         False
# 4  Rajesh Adimoolam (Tata Consultancy Services Ltd)         False
#
#   FacilityCode ClassType   CT    CT_Status CT_Indicator CT_Indicator_3
# ...

# %%
df1.drop(['CT','CT_Status','CT_Indicator'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#      Region        Metro SiteType DeploymentType                 NIDPM  \
# 0  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 1  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 2  AMEREAST   Des Moines       DC      Expansion          John Simmons
# 3  AMEREAST     Campinas      RNG            Aug           Kathy Brown
# 4  AMERWEST  Los Angeles       GW        Upgrade  Darren (Norm) Norman
#
#                                                 DPM  IsMainstream  \
# 0       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 1       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 2       Dhiraj Take (Tata Consultancy Services Ltd)         False
# 3          Madhvi Chand (Tata Consultancy Services)         False
# 4  Rajesh Adimoolam (Tata Consultancy Services Ltd)         False
#
#   FacilityCode ClassType CT_Indicator_3
# 0          DM4   Class A          Green
# 1          DM4   Class A          Green
# ...

# %%
exp_clf=setup(df1,target='CT_Indicator_3')
# Out:
# <style  type="text/css" >
# </style><table id="T_7b65d6be_801a_11eb_8dd3_002324755b86" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b65d6be_801a_11eb_8dd3_002324755b86level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7b65d6be_801a_11eb_8dd3_002324755b86row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7b65d6be_801a_11eb_8dd3_002324755b86row0_col1" class="data row0 col1" >7409</td>
#             </tr>
#             <tr>
#                         <th id="T_7b65d6be_801a_11eb_8dd3_002324755b86level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7b65d6be_801a_11eb_8dd3_002324755b86row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
best=compare_models()
# Out:
# <style  type="text/css" >
#     #T_e3fd1166_801a_11eb_af67_002324755b86 th {
#           text-align: left;
# ...

# %%
rf=create_model('rf')
# Out:
# <style  type="text/css" >
# #T_ec9692a4_801a_11eb_900d_002324755b86row10_col0,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col1,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col2,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col3,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col4,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col5,#T_ec9692a4_801a_11eb_900d_002324755b86row10_col6{
#             background:  yellow;
#         }</style><table id="T_ec9692a4_801a_11eb_900d_002324755b86" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tune_rf=tune_model(rf)
# Out:
# <style  type="text/css" >
# #T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col0,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col1,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col2,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col3,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col4,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col5,#T_fe4f07e3_801a_11eb_ba90_002324755b86row10_col6{
#             background:  yellow;
#         }</style><table id="T_fe4f07e3_801a_11eb_ba90_002324755b86" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(tune_rf)

# %%
plot_model(tune_rf,'confusion_matrix')

# %%
predictions = predict_model(tune_rf)
# Out:
# <style  type="text/css" >
# </style><table id="T_11fc7735_801b_11eb_97a8_002324755b86" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11fc7735_801b_11eb_97a8_002324755b86level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_11fc7735_801b_11eb_97a8_002324755b86row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
g
